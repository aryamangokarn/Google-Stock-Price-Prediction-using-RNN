# %% [markdown]
# # Recurrent Neural Network

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/google-stock-price/Google_Stock_Price_Test.csv
# /kaggle/input/google-stock-price/Google_Stock_Price_Train.csv

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing the training set

# %%
dataset_train = pd.read_csv('/kaggle/input/google-stock-price/Google_Stock_Price_Train.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# ### Creating a data structure with 60 timesteps and 1 output

# %%
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# ### Reshaping

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ## Part 2 - Building and Training the RNN

# %% [markdown]
# ### Importing the Keras libraries and packages

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation

# %% [markdown]
# ### Initialising the RNN

# %%
regressor = Sequential()

# %% [markdown]
# ### Adding the first LSTM layer and some Dropout regularisation

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %% [markdown]
# ### Adding a second LSTM layer and some Dropout regularisation

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %% [markdown]
# ### Adding a third LSTM layer and some Dropout regularisation

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %% [markdown]
# ### Adding a fourth LSTM layer and some Dropout regularisation

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %% [markdown]
# ### Adding the output layer

# %%
regressor.add(Dense(units = 1))

# %% [markdown]
# ### Compiling the RNN

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ### Fitting the RNN to the Training set

# %%
regressor.fit(X_train, y_train, epochs = 200, batch_size = 32)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 10s 97ms/step - loss: 0.0893
# Epoch 2/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0064
# Epoch 3/200
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0065
# Epoch 4/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0048
# Epoch 5/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0050
# Epoch 6/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0053
# Epoch 7/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0045
# Epoch 8/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0051
# Epoch 9/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0046
# Epoch 10/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0039
# Epoch 11/200
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0037
# Epoch 12/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0047
# Epoch 13/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0044
# Epoch 14/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0039
# Epoch 15/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0037
# Epoch 16/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0038
# Epoch 17/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0036
# Epoch 18/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0034
# Epoch 19/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0041
# Epoch 20/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0041
# Epoch 21/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0041
# Epoch 22/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0039
# Epoch 23/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0032
# Epoch 24/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0045
# Epoch 25/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0031
# Epoch 26/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0033
# Epoch 27/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0029
# Epoch 28/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0040
# Epoch 29/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0030
# Epoch 30/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0028
# Epoch 31/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0029
# Epoch 32/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0032
# Epoch 33/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0047
# Epoch 34/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0028
# Epoch 35/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0030
# Epoch 36/200
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0025
# Epoch 37/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0031
# Epoch 38/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0030
# Epoch 39/200
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0026
# Epoch 40/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0023
# Epoch 41/200
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0025
# Epoch 42/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0026
# Epoch 43/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0029
# Epoch 44/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0021
# Epoch 45/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0027
# Epoch 46/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0022
# Epoch 47/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0025
# Epoch 48/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0022
# Epoch 49/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0025
# Epoch 50/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0027
# Epoch 51/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0024
# Epoch 52/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0025
# Epoch 53/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0028
# Epoch 54/200
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0023
# Epoch 55/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0025
# Epoch 56/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0022
# Epoch 57/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0021
# Epoch 58/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0022
# Epoch 59/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0023
# Epoch 60/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0019
# Epoch 61/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0022
# Epoch 62/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0020
# Epoch 63/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0020
# Epoch 64/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0021
# Epoch 65/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0019
# Epoch 66/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0018
# Epoch 67/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0018
# Epoch 68/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0021
# Epoch 69/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0021
# Epoch 70/200
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0019
# Epoch 71/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0021
# Epoch 72/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0020
# Epoch 73/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0018
# Epoch 74/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0018
# Epoch 75/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0018
# Epoch 76/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0019
# Epoch 77/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0020
# Epoch 78/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0018
# Epoch 79/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0020
# Epoch 80/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0016
# Epoch 81/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0018
# Epoch 82/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0021
# Epoch 83/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0017
# Epoch 84/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0017
# Epoch 85/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0017
# Epoch 86/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0016
# Epoch 87/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0014
# Epoch 88/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0015
# Epoch 89/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0016
# Epoch 90/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0018
# Epoch 91/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0014
# Epoch 92/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0019
# Epoch 93/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0014
# Epoch 94/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0016
# Epoch 95/200
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0016
# Epoch 96/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0014
# Epoch 97/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0014
# Epoch 98/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0014
# Epoch 99/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0014
# Epoch 100/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0015
# Epoch 101/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0014
# Epoch 102/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0014
# Epoch 103/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0013
# Epoch 104/200
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0022
# Epoch 105/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0015
# Epoch 106/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0013
# Epoch 107/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0015
# Epoch 108/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0014
# Epoch 109/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0015
# Epoch 110/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 111/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0010
# Epoch 112/200
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0013
# Epoch 113/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0016
# Epoch 114/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0014
# Epoch 115/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0016
# Epoch 116/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0014
# Epoch 117/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0014
# Epoch 118/200
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0014
# Epoch 119/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0012
# Epoch 120/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0012
# Epoch 121/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0012
# Epoch 122/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 123/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 124/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0012
# Epoch 125/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 126/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 127/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0011
# Epoch 128/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0011
# Epoch 129/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0012
# Epoch 130/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0011
# Epoch 131/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0013
# Epoch 132/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0013
# Epoch 133/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0012
# Epoch 134/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0013
# Epoch 135/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 136/200
# 38/38 [==============================] - 4s 93ms/step - loss: 9.7813e-04
# Epoch 137/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 138/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0011
# Epoch 139/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0013
# Epoch 140/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0012
# Epoch 141/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0011
# Epoch 142/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0010
# Epoch 143/200
# 38/38 [==============================] - 4s 95ms/step - loss: 9.8352e-04
# Epoch 144/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0011
# Epoch 145/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0011
# Epoch 146/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0011
# Epoch 147/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0011
# Epoch 148/200
# 38/38 [==============================] - 4s 98ms/step - loss: 9.8508e-04
# Epoch 149/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0014
# Epoch 150/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0011
# Epoch 151/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0011
# Epoch 152/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0015
# Epoch 153/200
# 38/38 [==============================] - 3s 91ms/step - loss: 9.5920e-04
# Epoch 154/200
# 38/38 [==============================] - 4s 94ms/step - loss: 9.5272e-04
# Epoch 155/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 156/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0012
# Epoch 157/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0011
# Epoch 158/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 159/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0011
# Epoch 160/200
# 38/38 [==============================] - 4s 97ms/step - loss: 9.8966e-04
# Epoch 161/200
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0010
# Epoch 162/200
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0011
# Epoch 163/200
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0011
# Epoch 164/200
# 38/38 [==============================] - 3s 91ms/step - loss: 9.1370e-04
# Epoch 165/200
# 38/38 [==============================] - 3s 91ms/step - loss: 9.6561e-04
# Epoch 166/200
# 38/38 [==============================] - 4s 96ms/step - loss: 9.8274e-04
# Epoch 167/200
# 38/38 [==============================] - 4s 94ms/step - loss: 9.7110e-04
# Epoch 168/200
# 38/38 [==============================] - 4s 101ms/step - loss: 9.9864e-04
# Epoch 169/200
# 38/38 [==============================] - 4s 96ms/step - loss: 9.4979e-04
# Epoch 170/200
# 38/38 [==============================] - 4s 93ms/step - loss: 8.9710e-04
# Epoch 171/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0013
# Epoch 172/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0011
# Epoch 173/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0010
# Epoch 174/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0012
# Epoch 175/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0011
# Epoch 176/200
# 38/38 [==============================] - 4s 96ms/step - loss: 9.6483e-04
# Epoch 177/200
# 38/38 [==============================] - 4s 101ms/step - loss: 9.4629e-04
# Epoch 178/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0010
# Epoch 179/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0010
# Epoch 180/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0011
# Epoch 181/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0011
# Epoch 182/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0011
# Epoch 183/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0014
# Epoch 184/200
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0010
# Epoch 185/200
# 38/38 [==============================] - 4s 93ms/step - loss: 9.2599e-04
# Epoch 186/200
# 38/38 [==============================] - 4s 97ms/step - loss: 9.6034e-04
# Epoch 187/200
# 38/38 [==============================] - 4s 93ms/step - loss: 8.8866e-04
# Epoch 188/200
# 38/38 [==============================] - 4s 98ms/step - loss: 9.8539e-04
# Epoch 189/200
# 38/38 [==============================] - 4s 96ms/step - loss: 9.2181e-04
# Epoch 190/200
# 38/38 [==============================] - 4s 95ms/step - loss: 9.6541e-04
# Epoch 191/200
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0012
# Epoch 192/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0010
# Epoch 193/200
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0010
# Epoch 194/200
# 38/38 [==============================] - 4s 97ms/step - loss: 9.8284e-04
# Epoch 195/200
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0010
# Epoch 196/200
# 38/38 [==============================] - 4s 99ms/step - loss: 8.3434e-04
# Epoch 197/200
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0011
# Epoch 198/200
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0010
# Epoch 199/200
# 38/38 [==============================] - 4s 99ms/step - loss: 9.2632e-04
# Epoch 200/200
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0011

# %% [markdown]
# ## Part 3 - Making the predictions and visualising the results

# %% [markdown]
# ### Getting the real stock price of 2017

# %%
dataset_test = pd.read_csv('/kaggle/input/google-stock-price/Google_Stock_Price_Test.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# %% [markdown]
# ### Getting the predicted stock price of 2017

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %% [markdown]
# ### Visualising the results

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### This model uses LSTM in RNN and gives fairly accurately result on how the stock price of google varies.
